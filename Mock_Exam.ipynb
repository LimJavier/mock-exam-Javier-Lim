# %% [markdown]
# <a href="https://colab.research.google.com/github/LimJavier/mock-exam-Javier-Lim/blob/main/Mock_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Section X.Y - [Description]
# Course constraint: [Week X concept being practiced]

def add(a,b):
    """
    Returns the sum of two numbers.

    >>> add(1,2)
    3
    >>> add(-1,4)
    3
    """
    return a + b
    # Your implementation

if __name__ == "__main__":
    import doctest
    doctest.testmod(verbose=True)
# Out:
# Trying:
#     add(1,2)
# Expecting:
#     3
# ok
# Trying:
#     add(-1,4)
# Expecting:
#     3
# ok
# 1 items had no tests:
#     __main__
# 1 items passed all tests:
#    2 tests in __main__.add
# 2 tests in 2 items.
# 2 passed and 0 failed.
# Test passed.
